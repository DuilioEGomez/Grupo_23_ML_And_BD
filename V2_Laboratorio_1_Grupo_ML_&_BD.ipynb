# %% [markdown]
# *** Laboratorio Machine Learning & Big Data -
#  Análisis de Datos de Ventas Mensuales ***
#  * Galvez Juan Manuel Ignacio - Gomez Duilio Enrique - Munuce Juan José

# %% [markdown]
# Los codigos estan hechos para mostrar la informacion solicitada y otra informacion que consideramos relevante, para mas detalles leer el documento Word que se incluye en la entrega.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import datetime
from datetime import datetime
import calendar
import plotly.graph_objects as go
import plotly.express as px

# %%
ruta_de_archivos = '/content/drive/MyDrive/Colab Notebooks/Laboratorio 1' # ACA VA LA URL DEL GOOGLE DRIVE DEL ALUMNO
archivos = os.listdir(ruta_de_archivos)
ruta_completa = os.path.join(ruta_de_archivos, archivos[5])  # Ruta completa al archivo
df = pd.read_csv(ruta_completa)  # Cargar el archivo CSV en un DataFrame
df
# Out:
#       ID de Pedido                  Producto Cantidad Pedida Precio Unitario  \
# 0           222910  Apple Airpods Headphones               1             150
# 1           222911             Flatscreen TV               1             300
# 2           222912     AA Batteries (4-pack)               1            3.84
# 3           222913     AA Batteries (4-pack)               1            3.84
# 4           222914    AAA Batteries (4-pack)               5            2.99
# ...            ...                       ...             ...             ...
# 14366       236665          Wired Headphones               1           11.99
# 14367       236666              20in Monitor               1          109.99
# 14368       236667    AAA Batteries (4-pack)               1            2.99
# 14369       236668          Wired Headphones               1           11.99
# 14370       236669    AAA Batteries (4-pack)               1            2.99
#
# ...

# %%
ruta_de_archivos = '/content/drive/MyDrive/Colab Notebooks/Laboratorio 1'
archivos = os.listdir(ruta_de_archivos)
archivos
# Out:
# ['Dataset_de_ventas_Abril.csv',
#  'Dataset_de_ventas_Agosto.csv',
#  'Dataset_de_ventas_Diciembre.csv',
#  'Dataset_de_ventas_Enero.csv',
#  'Dataset_de_ventas_Febrero.csv',
#  'Dataset_de_ventas_Julio.csv',
#  'Dataset_de_ventas_Junio.csv',
#  'Dataset_de_ventas_Marzo.csv',
#  'Dataset_de_ventas_Mayo.csv',
#  'Dataset_de_ventas_Noviembre.csv',
#  'Dataset_de_ventas_Octubre.csv',
#  'Dataset_de_ventas_Septiembre.csv']

# %%
ruta_de_archivos = '/content/drive/MyDrive/Colab Notebooks/Laboratorio 1'
archivos = os.listdir(ruta_de_archivos)

dataframes= {}

for archivo in archivos:
    if archivo.endswith('.csv'):  # Asegurarse de que solo se consideren archivos CSV
        mes = archivo.split('_')[3].split('.')[0]  # Obtener el nombre del archivo sin la extensión
        ruta_completa = os.path.join(ruta_de_archivos, archivo)  # Ruta completa al archivo
        df = pd.read_csv(ruta_completa)  # Cargar el archivo CSV en un DataFrame
        df_ventas = df.copy()

        df_ventas['Cantidad Pedida'] = pd.to_numeric(df_ventas['Cantidad Pedida'], errors='coerce')  #El errors= 'coerce' transforma los valores no numericos a NaN'
        df_ventas['Precio Unitario'] = pd.to_numeric(df_ventas['Precio Unitario'], errors='coerce')


        df_ventas = df_ventas.loc[~df_ventas['Cantidad Pedida'].isna()]
        df_ventas = df_ventas.loc[~df_ventas['Precio Unitario'].isna()]

        # Elimino todos los Nan y me quedo solo con los valores numericos
        df_ventas = df_ventas.dropna()

        # Transformo todos los valores numericos al tipo de dato int
        df_ventas['Cantidad Pedida'] = df_ventas['Cantidad Pedida'].astype(int)
        df_ventas['Precio Unitario'] = df_ventas['Precio Unitario'].astype(int)

        dataframes[mes] = df_ventas  # Agregar el DataFrame al diccionario usando el nombre del mes

# %%
dataframes['Diciembre']
# Out:
#       ID de Pedido                    Producto  Cantidad Pedida  \
# 0           295665          Macbook Pro Laptop                1
# 1           295666          LG Washing Machine                1
# 2           295667        USB-C Charging Cable                1
# 3           295668            27in FHD Monitor                1
# 4           295669        USB-C Charging Cable                1
# ...            ...                         ...              ...
# 25112       319666    Lightning Charging Cable                1
# 25113       319667       AA Batteries (4-pack)                2
# 25114       319668             Vareebadd Phone                1
# 25115       319669            Wired Headphones                1
# 25116       319670  Bose SoundSport Headphones                1
#
#        Precio Unitario Fecha de Pedido                      Dirección de Envio
# 0                 1700  12/30/19 00:01  136 Church St, New York City, NY 10001
# ...

# %%
 # Creo el Dataframe ventas_anual que contiene todos los meses concatenados para hacer analisis anuales

ventas_anual = pd.concat(dataframes.values(), axis=0, ignore_index=True)

# %%
len(ventas_anual)
# Out:
# 185950

# %%
ventas_anual.iloc[90000]
# Out:
# ID de Pedido                                     235526
# Producto                           USB-C Charging Cable
# Cantidad Pedida                                       1
# Precio Unitario                                      11
# Fecha de Pedido                          07/27/19 22:29
# Dirección de Envio    160 Forest St, Portland, OR 97035
# Name: 90000, dtype: object

# %%
meses = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio',
        'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre']

for mes in meses:
    dataframe_mes = dataframes[mes]

# %%
def extraer_datos(datos):
  datos['Fecha de Pedido'] = pd.to_datetime(datos['Fecha de Pedido'])
  datos['Hora'] = datos['Fecha de Pedido'].dt.hour
  datos['Dia'] = datos['Fecha de Pedido'].dt.day
  datos['Mes'] = datos['Fecha de Pedido'].dt.month
  return datos

dataframe_mes = extraer_datos(dataframe_mes)

# %% [markdown]
# **1)  Comportamiento de las ventas en los distintos meses:**
# ---
# 1.   ¿Cómo variaron las ventas a lo largo de los diferentes meses?
# 2.   ¿Hubo algún mes que se destacó en términos de ventas?

# %%
# Creo listas para almacenar los totales de ventas y los nombres de los meses
totales_ventas = []
nombres_meses = []

for mes in meses:
    dataframe_mes = dataframes[mes]
    dataframe_mes = extraer_datos(dataframe_mes)

    total_ventas_mes = dataframe_mes['Cantidad Pedida'].sum()
    totales_ventas.append(total_ventas_mes)
    nombres_meses.append(mes)

# Creo el objeto figura con el gráfico de barras
fig = go.Figure()

fig.add_trace(go.Bar(
    x=nombres_meses,
    y=totales_ventas,
    marker=dict(color=totales_ventas, colorscale = 'RdYlGn', colorbar=dict(title="Total de ventas", x=1.0, thickness=15)),  # Color y barra de colores
    text=totales_ventas,
    textposition='auto',  # Muestro el valor encima de las barras

))

# Configuro los ejes y los títulos
fig.update_layout(
    title="Cantidad total de ventas por mes",
    xaxis=dict(title="Meses"),
    yaxis=dict(title="Ventas"),
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_ventas
# Out:
#       ID de Pedido                Producto  Cantidad Pedida  Precio Unitario  \
# 0           248151   AA Batteries (4-pack)                4                3
# 1           248152    USB-C Charging Cable                2               11
# 2           248153    USB-C Charging Cable                1               11
# 3           248154        27in FHD Monitor                1              149
# 4           248155    USB-C Charging Cable                1               11
# ...            ...                     ...              ...              ...
# 11681       259353  AAA Batteries (4-pack)                3                2
# 11682       259354                  iPhone                1              700
# 11683       259355                  iPhone                1              700
# 11684       259356  34in Ultrawide Monitor                1              379
# 11685       259357    USB-C Charging Cable                1               11
#
# ...

# %%
totales_ventas,
# Out:
# ([10868,
#   13461,
#   17006,
#   20568,
#   18657,
#   15255,
#   16069,
#   13442,
#   13119,
#   22705,
#   19808,
#   28121],)

# %% [markdown]
# 1.3 ¿Cual es el ingreso total generado por mes?

# %%
import plotly.graph_objects as go

meses = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre']

totales_ventas = []
nombres_meses = []

for mes in meses:
  dataframe_mes = dataframes[mes]
  dataframes_mes = extraer_datos(dataframe_mes)

  #total_ventas_mes = dataframe_mes['Cantidad Pedida'].sum()
  dataframe_mes['Ventas_totales'] = dataframe_mes['Precio Unitario'] * dataframe_mes['Cantidad Pedida']
  total_ventas_mes = dataframe_mes['Ventas_totales'].sum()

  totales_ventas.append(round(total_ventas_mes,2))
  nombres_meses.append(mes)

fig = go.Figure()

# Agrego al objeto figura un grafico de barra conn los valores extraidos previamente
fig.add_trace(go.Bar(
        x= nombres_meses,
        y=  totales_ventas,
        yaxis="y",
        name="Ventas Totales por Mes",
        marker = dict(color= totales_ventas, colorscale = 'RdYlGn',colorbar = dict(title = "Ventas Mensuales")),
        text = totales_ventas,
        textposition = 'auto'
))

# Configuro titulos y ejes del grafico
fig.update_layout(
    title="Ingresos por Ventas Mensuales",
    xaxis=dict(title="Meses"),
    yaxis=dict(title="Montos Vendidos", side="left"))


## Muestro el grafico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
totales_ventas
# Out:
# [1807060,
#  2193144,
#  2796031,
#  3380338,
#  3130267,
#  2566675,
#  2634571,
#  2234143,
#  2088683,
#  3719364,
#  3183687,
#  4597677]

# %% [markdown]
# ***2. Optimización de la publicidad y patrón de ventas por hora:***
#
# ¿Cuál es el momento ideal del día para presentar la publicidad y aumentar la
# probabilidad de compra?
#
# ¿Cómo cambian los patrones de ventas por hora a lo largo del año?
#
# ¿Hay modificaciones en los patrones de ventas durante las horas de mayor actividad
# en los distintos meses?

# %%
Horas = list(range(24))

# Creo el objeto figura
fig = go.Figure()

for mes in meses:
    dataframe_mes = dataframes[mes]
    dataframe_mes = extraer_datos(dataframe_mes)  # Reemplaza esto con el procesamiento que necesites
    Ventas_por_hora = dataframe_mes.groupby('Hora')['Cantidad Pedida'].count()



    # Agrego al objeto figura un gráfico de línea con las horas y las ventas por hora
    fig.add_trace(go.Scatter(
        x=Horas,
        y=Ventas_por_hora,
        mode='lines',
        name=mes,
        line=dict(width=2,shape='spline'),
    ))

# Configuro los ejes y los títulos
fig.update_layout(
    title="Unidades vendidas por hora en diferentes meses",
    xaxis=dict(title="Horas", tickvals=Horas),
    yaxis=dict(title="Unidades vendidas", side="left"),
    legend=dict(y=0.3, yanchor='bottom'),
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Analizamos las horas con más pedidos, y con menos pedidos en horarios diurnos

# %%
Horas = list(range(24))

# Creo el objeto figura
fig = go.Figure()
horas_analizadas = [12, 16, 19]

for hora in horas_analizadas:
    total_productos_vendidos = []

    for mes in meses:
        dataframe_mes = dataframes[mes]
        dataframe_mes = extraer_datos(dataframe_mes)  # Reemplaza esto con el procesamiento que necesites

        ventas_hora = dataframe_mes[dataframe_mes['Hora'] == hora]

        # Calcular la cantidad total de productos vendidos para la hora actual
        total_productos_vendidos.append(ventas_hora['Cantidad Pedida'].count())

    # Agrego al objeto figura un gráfico de línea con las horas y las ventas por hora
    fig.add_trace(go.Scatter(
        x=meses,
        y=total_productos_vendidos,
        mode='lines',
        name=f'{hora} horas',
        line=dict(width=2, shape='spline'),
    ))

# Configuro los ejes y los títulos
fig.update_layout(
    title="Unidades vendidas por hora",
    xaxis=dict(title="Meses", tickvals=Horas),
    yaxis=dict(title="Unidades vendidas", side="left"),
    legend=dict(y=0.3, yanchor='bottom'),
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_ventas
# Out:
#       ID de Pedido                Producto  Cantidad Pedida  Precio Unitario  \
# 0           248151   AA Batteries (4-pack)                4                3
# 1           248152    USB-C Charging Cable                2               11
# 2           248153    USB-C Charging Cable                1               11
# 3           248154        27in FHD Monitor                1              149
# 4           248155    USB-C Charging Cable                1               11
# ...            ...                     ...              ...              ...
# 11681       259353  AAA Batteries (4-pack)                3                2
# 11682       259354                  iPhone                1              700
# 11683       259355                  iPhone                1              700
# 11684       259356  34in Ultrawide Monitor                1              379
# 11685       259357    USB-C Charging Cable                1               11
#
# ...

# %% [markdown]
# 3) Distribución de ventas por ubicación:
#
# *    ¿En qué ciudades se han registrado las mayores ventas?
# *   ¿Cómo se comparan las ventas en diferentes estados o regiones?
# *   ¿Existe variación en las ventas por estado a lo largo de los meses?Elemento de lista

# %%
# se cre un DF con las direcciones de envio y se le crea tres columnas 'Calle', 'Ciudad','PO BOX'
#########direccion_df = df_ventas['Dirección de Envio'].str.split(', ',expand=True)
direccion_df = ventas_anual['Dirección de Envio'].str.split(', ',expand=True)
direccion_df.columns = ['Calle','Ciudad','PO BOX']

# se hace un split del valor de cada direccion y se separa cargando en la columna correspondiente el ESTADO, COD Postal y PO BOX
direccion_df[['Estado', 'Cod Postal']] = direccion_df['PO BOX'].str.split(' ',expand=True)

# se concatena el DF Ventas y el DF Direccion en un dataframe llamado ventas_desglosado
ventas_anual = pd.concat([ventas_anual,direccion_df],axis=True)
ventas_desglosado = ventas_anual.dropna()

# %%
ventas_desglosado
# Out:
#        ID de Pedido                    Producto  Cantidad Pedida  \
# 0            176558        USB-C Charging Cable                2
# 1            176559  Bose SoundSport Headphones                1
# 2            176560                Google Phone                1
# 3            176560            Wired Headphones                1
# 4            176561            Wired Headphones                1
# ...             ...                         ...              ...
# 185945       259353      AAA Batteries (4-pack)                3
# 185946       259354                      iPhone                1
# 185947       259355                      iPhone                1
# 185948       259356      34in Ultrawide Monitor                1
# 185949       259357        USB-C Charging Cable                1
#
#         Precio Unitario Fecha de Pedido  \
# 0                    11  04/19/19 08:46
# 1                    99  04/07/19 22:30
# 2                   600  04/12/19 14:38
# ...

# %% [markdown]
# **3.1** Ventas por Ciudad

# %%
# Creo el DF Ciudades con la ciudad y su cantidad pedida

####df_ciudades = pd.DataFrame(ventas_desglosado)

df_auxiliar_ciudades = ventas_desglosado[['Ciudad', 'Cantidad Pedida']]

# Ordeno el DataFrame auxiliar por 'Cantidad Pedida' por ciudad
df_auxiliar_ciudades = df_auxiliar_ciudades.groupby('Ciudad').sum().reset_index()
df_auxiliar_ciudades = df_auxiliar_ciudades.sort_values(by='Cantidad Pedida', ascending=False)

print(df_auxiliar_ciudades)
# Out:
#           Ciudad  Cantidad Pedida
# 7  San Francisco            50239
# 4    Los Angeles            33289
# 5  New York City            27932
# 2         Boston            22528
# 3         Dallas            16730
# 0        Atlanta            16602
# 8        Seattle            16553
# 6       Portland            14053
# 1         Austin            11153

# %% [markdown]
# Grafica de Torta, indicando Ciudades con mayor cantidad de ventas

# %%
# Con los datos de las ciudades y su cantidad pedida dibujamos una torta detallando la que mas cantidad pedida posee separada del grafico principal

fig = go.Figure(data=[go.Pie(labels=df_auxiliar_ciudades['Ciudad'], values=df_auxiliar_ciudades['Cantidad Pedida'], pull=[0.15, 0, 0, 0])])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **3.2** Ventas por Estados

# %%
df = pd.DataFrame(ventas_desglosado)
# creo un dataframe auxiliar de los estados con sus cantidades pedidas
df_auxiliar_estados = df[['Estado', 'Cantidad Pedida']]

# Ordeno el DataFrame auxiliar por 'Cantidad Pedida' por estado
df_auxiliar_estados = df_auxiliar_estados.groupby('Estado').sum().reset_index() # agrupo por 'Estado' y reseteo el indice
df_auxiliar_estados = df_auxiliar_estados.sort_values(by='Cantidad Pedida', ascending=False) # ordeno los estados por cantidad mas pedidas

print(df_auxiliar_estados)
# Out:
#   Estado  Cantidad Pedida
# 0     CA            83528
# 4     NY            27932
# 6     TX            27883
# 2     MA            22528
# 1     GA            16602
# 7     WA            16553
# 5     OR            11303
# 3     ME             2750

# %% [markdown]
# Grafica de Mapas por estado de EEUU por candidad de pedidos

# %%
#Se Grafica los estados de USA segun su cantidad de pedidos.

fig = px.choropleth(df_auxiliar_estados, locations='Estado', locationmode='USA-states',color='Cantidad Pedida',
                           color_continuous_scale="RdYlGn",
                           scope="usa",
                          title= 'Ventas por estado',
                        )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
len(ventas_desglosado)
# Out:
# 185950

# %% [markdown]
# **3.3** Variacion ventas estados / meses

# %%
ventas_desglosado
# Out:
#        ID de Pedido                    Producto  Cantidad Pedida  \
# 0            176558        USB-C Charging Cable                2
# 1            176559  Bose SoundSport Headphones                1
# 2            176560                Google Phone                1
# 3            176560            Wired Headphones                1
# 4            176561            Wired Headphones                1
# ...             ...                         ...              ...
# 185945       259353      AAA Batteries (4-pack)                3
# 185946       259354                      iPhone                1
# 185947       259355                      iPhone                1
# 185948       259356      34in Ultrawide Monitor                1
# 185949       259357        USB-C Charging Cable                1
#
#         Precio Unitario Fecha de Pedido  \
# 0                    11  04/19/19 08:46
# 1                    99  04/07/19 22:30
# 2                   600  04/12/19 14:38
# ...

# %%
########## Ya tengo el dataframe auxiliar llamado ventas_desglosado_YEAR donde estan los ESTADOS, MES y CANTIDAD PEDIDA ordenados
########## por MES donde se indica el estado que mas cantidad pedida ese mes

nombres_meses = [
    'Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio',
    'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre' # creo este arreglo para sincornizar el numero de mes con el Nombre del Mes
]

ventas_desglosado['Fecha de Pedido'] = pd.to_datetime(ventas_desglosado['Fecha de Pedido'])
ventas_desglosado_YEAR = pd.DataFrame({
    'Mes': ventas_desglosado['Fecha de Pedido'].dt.month,
    'Estado': ventas_desglosado['Estado'],
    'Cantidad Pedida': ventas_desglosado['Cantidad Pedida'],
})

ventas_desglosado_YEAR['Nombre Mes'] = ventas_desglosado_YEAR['Mes'].apply(lambda x: nombres_meses[x - 1])

# Agrupa por 'Estado' y 'Mes', calcula la suma de 'Cantidad Pedida' y resetea el índice
resumen_ventas = ventas_desglosado_YEAR.groupby(['Estado', 'Mes','Nombre Mes'])['Cantidad Pedida'].sum().reset_index()

# Ordena el DataFrame por 'Estado' y 'Mes' según la suma de 'Cantidad Pedida'
resumen_ventas = resumen_ventas.sort_values(by=['Mes'])

# Imprime el DataFrame ordenado
print(resumen_ventas)
# Out:
#    Estado  Mes Nombre Mes  Cantidad Pedida
# 0      CA    1      Enero             4377
# 24     MA    1      Enero             1174
# 48     NY    1      Enero             1513
# 60     OR    1      Enero              555
# 12     GA    1      Enero              876
# ..    ...  ...        ...              ...
# 35     MA   12  Diciembre             3026
# 23     GA   12  Diciembre             2225
# 11     CA   12  Diciembre            11165
# 83     TX   12  Diciembre             3821
# 95     WA   12  Diciembre             2203
#
# [96 rows x 4 columns]

# %%
fig = px.bar(resumen_ventas, x=resumen_ventas['Nombre Mes'], y=resumen_ventas['Cantidad Pedida'], color=resumen_ventas['Estado'], title="Cantidad Pedida por Mes/Estado")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 4. Análisis del producto más vendido:
#
# *  ¿Cuál es el producto más vendido en general y en cada mes?
# *   ¿Qué factores crees que han contribuido al éxito de ese producto en particular?

# %%
fig = go.Figure()

lista_productos = []
totales_ventas = []

for mes in meses:
  dataframe_mes = dataframes[mes]
  dataframe_mes = extraer_datos(dataframe_mes)
  # Agrupar por Producto y sumar la Cantidad Pedida para obtener la cantidad total vendida por producto
  producto_mas_vendido = dataframe_mes.groupby('Producto')['Cantidad Pedida'].sum().reset_index()
  # Encontrar el producto más vendido
  producto_mas_vendido = producto_mas_vendido.sort_values(by='Cantidad Pedida', ascending=False).head(1)
  # Obtener el nombre y la cantidad vendida del producto más vendido
  nombre_mas_vendido = producto_mas_vendido['Producto'].values[0]
  cantidad_vendida = producto_mas_vendido['Cantidad Pedida'].values[0]
  totales_ventas.append(cantidad_vendida)
  lista_productos.append(nombre_mas_vendido)


# Agrego al objeto figura un gráfico de línea con las horas y las ventas por hora
fig.add_trace(go.Bar(
    x=meses,
    y=totales_ventas,
    text=lista_productos,  # Usar lista de nombres como texto
    textposition='inside',  # Posición del texto dentro de las barras
    marker=dict(color=totales_ventas, colorscale='RdYlGn', colorbar=dict(title="Total de ventas", x=1.0, thickness=15)),  # Color y barra de colores
))

# Configuro los ejes y los títulos
fig.update_layout(
  title="Producto mas vendido por mes",
  xaxis=dict(title="Mes", tickvals=Horas),
  yaxis=dict(title="Unidades vendidas", side="left"),
  legend=dict(y=0.3, yanchor='bottom'),
)



fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **5. Tendencia ventas:**
#
# ● ¿Existe alguna tendencia o patrón en las ventas que se repita a lo largo de los días en los diferentes meses?
#
# ● ¿Cómo varían las ventas a lo largo de los diferentes días de la semana?
#
# ● ¿Se observa alguna diferencia significativa en las ventas entre los días laborables y los fines de semana?

# %%
def extraer_datos_Igna(datos):
    datos['Fecha de Pedido'] = pd.to_datetime(datos['Fecha de Pedido'])
    datos['Hora'] = datos['Fecha de Pedido'].dt.hour
    datos['Dia'] = datos['Fecha de Pedido'].dt.day
    datos['Dia de la Semana'] = datos['Fecha de Pedido'].dt.day_name()
    return datos

# Lista de nombres de los meses y los dataframes correspondientes
meses = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre']

# Diccionario para traducir los nombres de los días de la semana
traduccion_dias = {
    0: 'Lunes',
    1: 'Martes',
    2: 'Miércoles',
    3: 'Jueves',
    4: 'Viernes',
    5: 'Sábado',
    6: 'Domingo'
}

# Fecha de inicio conocida (primer día de enero de 2019)
fecha_conocida = datetime(2019, 1, 1)

# Dentro del bucle para cada mes
for mes in meses:
    dataframe_mes = dataframes[mes]
    dataframe_mes = extraer_datos_Igna(dataframe_mes)

    # Convierte la columna 'Fecha de Pedido' en formato de fecha
    dataframe_mes['Fecha de Pedido'] = pd.to_datetime(dataframe_mes['Fecha de Pedido'], format='%m/%d/%y %H:%M')

    # Calcula el total de unidades vendidas por día y el día de la semana
    dataframe_mes['Dia del Mes'] = dataframe_mes['Fecha de Pedido'].dt.day

    # Calcula el número máximo de días en el mes actual usando el módulo calendar
    mes_actual = meses.index(mes) + 1
    max_dia_mes = calendar.monthrange(2019, mes_actual)[1]

    # Agrupa por día del mes y suma las unidades vendidas
    ventas_por_dia_mes = dataframe_mes.groupby('Dia del Mes')['Cantidad Pedida'].sum().reset_index()

    # Filtra solo los días del mes actual
    ventas_por_dia_mes = ventas_por_dia_mes[ventas_por_dia_mes['Dia del Mes'] <= max_dia_mes]

    # Crea el gráfico de barras con la escala de color 'RdYlGn'
    fig_mes = px.bar(ventas_por_dia_mes, x='Dia del Mes', y='Cantidad Pedida',
                     title=f'Ventas por día en {mes}', labels={'Dia del Mes': 'Día del Mes', 'Cantidad Pedida': 'Unidades Vendidas'},
                     color='Cantidad Pedida', color_continuous_scale='RdYlGn')

    # Calcula los nombres de los días de la semana dinámicamente
    dias_semana = []

    # Obtén el día de la semana para el primer día del mes actual
    primer_dia_mes = datetime(2019, mes_actual, 1).weekday()

    # Llena la lista de nombres de días para el mes actual
    for dia in range(1, max_dia_mes + 1):
        dia_semana = (primer_dia_mes + dia - 1) % 7
        nombre_dia = traduccion_dias[dia_semana]
        dias_semana.append(nombre_dia)

    # Configura el texto dentro de las barras con el nombre del día y el total de ventas
    text_labels = [f'{nombre_dia}<br>{cantidad}' for nombre_dia, cantidad in zip(dias_semana, ventas_por_dia_mes['Cantidad Pedida'])]
    fig_mes.update_traces(text=text_labels, textposition='inside', textangle=90, showlegend=False)

    # Establece valores específicos en el eje x y muestra el gráfico
    fig_mes.update_xaxes(tickvals=list(range(1, max_dia_mes + 1)), ticktext=list(range(1, max_dia_mes + 1)))
    fig_mes.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 5.1 Analizo los pedidos segun el día de la semana en todos los meses

# %%
def extraer_nombre_dia(datos):
  datos['Dia de la Semana'] = datos['Fecha de Pedido'].dt.day_name()
  return datos

# Combinar todos los DataFrames de los meses en uno solo
df_ventas_totales = pd.concat(dataframes.values(), ignore_index=True)

# Asegurarnos de que la columna 'Fecha de Pedido' esté en formato datetime
df_ventas_totales['Fecha de Pedido'] = pd.to_datetime(df_ventas_totales['Fecha de Pedido'], format='%m/%d/%y %H:%M')

# Crear una nueva columna 'Dia de la Semana' en el DataFrame combinado
df_ventas_totales['Dia de la Semana'] = df_ventas_totales['Fecha de Pedido'].dt.day_name()

# Traducir los nombres de los días al español
traduccion_dias = {
    'Monday': 'Lunes',
    'Tuesday': 'Martes',
    'Wednesday': 'Miércoles',
    'Thursday': 'Jueves',
    'Friday': 'Viernes',
    'Saturday': 'Sábado',
    'Sunday': 'Domingo'
}

df_ventas_totales['Dia de la Semana'] = df_ventas_totales['Dia de la Semana'].map(traduccion_dias)

# Calcular el total de ventas por día de la semana
total_ventas_por_dia_semana = df_ventas_totales.groupby('Dia de la Semana')['Cantidad Pedida'].sum().reset_index()

# Crear el gráfico de barras
fig = px.bar(total_ventas_por_dia_semana, x='Dia de la Semana', y='Cantidad Pedida',
             title='Total de Ventas por Día de la Semana en todo el año',
             labels={'Día de la Semana': 'Día de la Semana', 'Cantidad Pedida': 'Total de Ventas'},
             color='Dia de la Semana', color_discrete_sequence=px.colors.qualitative.Set3,
             text='Cantidad Pedida')

# Configurar el gráfico
fig.update_xaxes(categoryorder='array', categoryarray=['Lunes', 'Martes', 'Miércoles', 'Jueves', 'Viernes', 'Sábado', 'Domingo'])
fig.update_yaxes(range=[0, 35000])

# Mostrar el gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Total de Ventas por Día de la Semana Mes a Mes

# %%
def extraer_datos_Igna_2(datos):
    datos['Fecha de Pedido'] = pd.to_datetime(datos['Fecha de Pedido'])
    datos['Dia de la Semana'] = datos['Fecha de Pedido'].dt.day_name()
    return datos

# Lista de nombres de los meses y los dataframes correspondientes
meses = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre']

# Diccionario para traducir los nombres de los días de la semana
traduccion_dias = {
    'Monday': 'Lunes',
    'Tuesday': 'Martes',
    'Wednesday': 'Miércoles',
    'Thursday': 'Jueves',
    'Friday': 'Viernes',
    'Saturday': 'Sábado',
    'Sunday': 'Domingo'
}

# Rango deseado para el eje y
rango_y = [0, 5000]

# Rango de colores personalizado
rango_colores = [1200, 5000]

# Dentro del bucle para cada mes
for mes in meses:
    dataframe_mes = dataframes[mes]
    dataframe_mes = extraer_datos_Igna_2(dataframe_mes)

    # Convierte la columna 'Fecha de Pedido' en formato de fecha
    dataframe_mes['Fecha de Pedido'] = pd.to_datetime(dataframe_mes['Fecha de Pedido'], format='%m/%d/%y %H:%M')

    # Traduce los nombres de los días de la semana al español
    dataframe_mes['Dia de la Semana'] = dataframe_mes['Dia de la Semana'].map(traduccion_dias)

    # Calcula el total de unidades vendidas por día de la semana
    ventas_por_dia_semana = dataframe_mes.groupby('Dia de la Semana')['Cantidad Pedida'].sum().reset_index()

    # Crea el gráfico de barras con el rango de colores personalizado
    fig_mes = px.bar(ventas_por_dia_semana, x='Dia de la Semana', y='Cantidad Pedida',
                     title=f'Total de Ventas por Día de la Semana en {mes}',
                     labels={'Día de la Semana': 'Día de la Semana', 'Cantidad Pedida': 'Unidades Vendidas'},
                     color='Cantidad Pedida', color_continuous_scale='RdYlGn',
                     range_color=rango_colores)

    # Configura el gráfico
    fig_mes.update_xaxes(categoryorder='array', categoryarray=['Lunes', 'Martes', 'Miércoles', 'Jueves', 'Viernes', 'Sábado', 'Domingo'])

    # Configura el rango del eje y
    fig_mes.update_yaxes(range=rango_y)

    # Muestra el gráfico
    fig_mes.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Codigo gráficos ventas por día de cada mes

# %%
def extraer_datos_4(datos):
    datos['Fecha de Pedido'] = pd.to_datetime(datos['Fecha de Pedido'])
    datos['Hora'] = datos['Fecha de Pedido'].dt.hour
    datos['Dia'] = datos['Fecha de Pedido'].dt.day
    datos['Dia de la Semana'] = datos['Fecha de Pedido'].dt.day_name()
    return datos

# Lista de nombres de los meses y los dataframes correspondientes
meses = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre']

# Diccionario para traducir los nombres de los días de la semana
traduccion_dias = {
    0: 'Lunes',
    1: 'Martes',
    2: 'Miércoles',
    3: 'Jueves',
    4: 'Viernes',
    5: 'Sábado',
    6: 'Domingo'
}

# Fecha de inicio conocida (primer día de enero de 2019)
fecha_conocida = datetime(2019, 1, 1)

# Dentro del bucle para cada mes
for mes in meses:
    dataframe_mes = dataframes[mes]
    dataframe_mes = extraer_datos_4(dataframe_mes)

    # Convierte la columna 'Fecha de Pedido' en formato de fecha
    dataframe_mes['Fecha de Pedido'] = pd.to_datetime(dataframe_mes['Fecha de Pedido'], format='%m/%d/%y %H:%M')

    # Calcula el total de unidades vendidas por día y el día de la semana
    dataframe_mes['Dia del Mes'] = dataframe_mes['Fecha de Pedido'].dt.day

    # Calcula el número máximo de días en el mes actual usando el módulo calendar
    mes_actual = meses.index(mes) + 1
    max_dia_mes = calendar.monthrange(2019, mes_actual)[1]

    # Agrupa por día del mes y suma las unidades vendidas
    ventas_por_dia_mes = dataframe_mes.groupby('Dia del Mes')['Cantidad Pedida'].sum().reset_index()

    # Filtra solo los días del mes actual
    ventas_por_dia_mes = ventas_por_dia_mes[ventas_por_dia_mes['Dia del Mes'] <= max_dia_mes]

    # Crea el gráfico de barras con la escala de color 'RdYlGn'
    fig_mes = px.bar(ventas_por_dia_mes, x='Dia del Mes', y='Cantidad Pedida',
                     title=f'Ventas por día en {mes}', labels={'Dia del Mes': 'Día del Mes', 'Cantidad Pedida': 'Unidades Vendidas'},
                     color='Cantidad Pedida', color_continuous_scale='RdYlGn',
                     range_color=[300, 1100])  # Establece el rango de color de 300 a 1100

    # Establece la propiedad 'marker' para personalizar el color de las barras individualmente
    fig_mes.update_traces(marker=dict(color=ventas_por_dia_mes['Cantidad Pedida'],
                                  colorbar=dict(title='Cantidad Pedida',
                                                titleside='right',
                                                tickvals=[300, 700, 1100],
                                                ticks='inside',
                                                ticktext=['300', '700', '1100'])))

    # Calcula los nombres de los días de la semana dinámicamente
    dias_semana = []

    # Obtén el día de la semana para el primer día del mes actual
    primer_dia_mes = datetime(2019, mes_actual, 1).weekday()

    # Llena la lista de nombres de días para el mes actual
    for dia in range(1, max_dia_mes + 1):
        dia_semana = (primer_dia_mes + dia - 1) % 7
        nombre_dia = traduccion_dias[dia_semana]
        dias_semana.append(nombre_dia)

    # Configura el texto dentro de las barras con el nombre del día y el total de ventas
    text_labels = [f'{nombre_dia}<br>{cantidad}' for nombre_dia, cantidad in zip(dias_semana, ventas_por_dia_mes['Cantidad Pedida'])]
    fig_mes.update_traces(text=text_labels, textposition='inside', textangle=90, showlegend=False)

    # Establece el rango del eje y
    fig_mes.update_layout(yaxis=dict(range=[0, 1100]))

    # Establece valores específicos en el eje x y muestra el gráfico
    fig_mes.update_xaxes(tickvals=list(range(1, max_dia_mes + 1)), ticktext=list(range(1, max_dia_mes + 1)))
    fig_mes.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Codigo gráficos ventas por día DE LA SEMANA de cada mes

# %%
def extraer_datos_5(datos):
    datos['Fecha de Pedido'] = pd.to_datetime(datos['Fecha de Pedido'])
    datos['Dia de la Semana'] = datos['Fecha de Pedido'].dt.day_name()
    return datos

# Lista de nombres de los meses y los dataframes correspondientes
meses = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre']

# Diccionario para traducir los nombres de los días de la semana
traduccion_dias = {
    'Monday': 'Lunes',
    'Tuesday': 'Martes',
    'Wednesday': 'Miércoles',
    'Thursday': 'Jueves',
    'Friday': 'Viernes',
    'Saturday': 'Sábado',
    'Sunday': 'Domingo'
}

# Rango deseado para el eje y
rango_y = [0, 5000]

# Rango de colores personalizado
rango_colores = [1200, 5000]

# Dentro del bucle para cada mes
for mes in meses:
    dataframe_mes = dataframes[mes]
    dataframe_mes = extraer_datos_5(dataframe_mes)

    # Convierte la columna 'Fecha de Pedido' en formato de fecha
    dataframe_mes['Fecha de Pedido'] = pd.to_datetime(dataframe_mes['Fecha de Pedido'], format='%m/%d/%y %H:%M')

    # Traduce los nombres de los días de la semana al español
    dataframe_mes['Dia de la Semana'] = dataframe_mes['Dia de la Semana'].map(traduccion_dias)

    # Calcula el total de unidades vendidas por día de la semana
    ventas_por_dia_semana = dataframe_mes.groupby('Dia de la Semana')['Cantidad Pedida'].sum().reset_index()

    # Crea el gráfico de barras con el rango de colores personalizado
    fig_mes = px.bar(ventas_por_dia_semana, x='Dia de la Semana', y='Cantidad Pedida',
                     title=f'Total de Ventas por Día de la Semana en {mes}',
                     labels={'Dia de la Semana': 'Día de la Semana', 'Cantidad Pedida': 'Unidades Vendidas'},
                     color='Cantidad Pedida', color_continuous_scale='RdYlGn',
                     range_color=rango_colores)

    # Configura el gráfico
    fig_mes.update_xaxes(categoryorder='array', categoryarray=['Lunes', 'Martes', 'Miércoles', 'Jueves', 'Viernes', 'Sábado', 'Domingo'])

    # Configura el rango del eje y
    fig_mes.update_yaxes(range=rango_y)

    # Muestra el gráfico
    fig_mes.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Codigo gráficos ventas totales por día DE LA SEMANA de todo el año

# %%
# Combinar todos los DataFrames de los meses en uno solo
df_ventas_totales = pd.concat(dataframes.values(), ignore_index=True)

# Asegurarnos de que la columna 'Fecha de Pedido' esté en formato datetime
df_ventas_totales['Fecha de Pedido'] = pd.to_datetime(df_ventas_totales['Fecha de Pedido'], format='%m/%d/%y %H:%M')

# Crear una nueva columna 'Dia de la Semana' en el DataFrame combinado
df_ventas_totales['Dia de la Semana'] = df_ventas_totales['Fecha de Pedido'].dt.day_name()

# Traducir los nombres de los días al español
traduccion_dias = {
    'Monday': 'Lunes',
    'Tuesday': 'Martes',
    'Wednesday': 'Miércoles',
    'Thursday': 'Jueves',
    'Friday': 'Viernes',
    'Saturday': 'Sábado',
    'Sunday': 'Domingo'
}

df_ventas_totales['Dia de la Semana'] = df_ventas_totales['Dia de la Semana'].map(traduccion_dias)

# Calcular el total de ventas por día de la semana
total_ventas_por_dia_semana = df_ventas_totales.groupby('Dia de la Semana')['Cantidad Pedida'].sum().reset_index()


# Crear el gráfico de barras
fig = px.bar(total_ventas_por_dia_semana, x='Dia de la Semana', y='Cantidad Pedida',
             title='Total de Ventas por Día de la Semana en todo el año',
             labels={'Dia de la Semana': 'Día de la Semana', 'Cantidad Pedida': 'Total de Ventas'},
             color='Dia de la Semana', color_discrete_sequence=px.colors.qualitative.Set3,
             text='Cantidad Pedida')

# Configurar el gráfico
fig.update_xaxes(categoryorder='array', categoryarray=['Lunes', 'Martes', 'Miércoles', 'Jueves', 'Viernes', 'Sábado', 'Domingo'])
fig.update_yaxes(range=[0, 35000])

# Configurar la leyenda para que siga el orden del eje x
fig.update_traces(legendgroup='Dia de la Semana')

# Mostrar el gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
